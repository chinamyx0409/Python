# %%
import pandas as pd
df_gender = pd.read_csv('D:\\Python\\titanic\\gender_submission.csv')
df_test = pd.read_csv('D:\\Python\\titanic\\test.csv')
df_train = pd.read_csv('D:\\Python\\titanic\\train.csv')

# %%
df_test
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# ...

# %%
df_train
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df_gender
# Out:
#      PassengerId  Survived
# 0            892         0
# 1            893         1
# 2            894         0
# 3            895         0
# 4            896         1
# ..           ...       ...
# 413         1305         0
# 414         1306         1
# 415         1307         0
# 416         1308         0
# 417         1309         0
#
# [418 rows x 2 columns]

# %%
#df_train[['Sex']] = df_train[['Sex']].apply([lambda x : 0 if x =='female' else 1])

# %%
m = pd.DataFrame()
for x,y in df_train.groupby(['Pclass','Sex']):
    print(x)
    print(y.Fare)
    m = y
    
    
    print('_'*10)
# Out:
# (1, 'female')
# 1       71.2833
# 3       53.1000
# 11      26.5500
# 31     146.5208
# 52      76.7292
#          ...
# 856    164.8667
# 862     25.9292
# 871     52.5542
# 879     83.1583
# 887     30.0000
# Name: Fare, Length: 94, dtype: float64
# __________
# (1, 'male')
# 6       51.8625
# 23      35.5000
# 27     263.0000
# 30      27.7208
# 34      82.1708
#          ...
# 839     29.7000
# 857     26.5500
# 867     50.4958
# 872      5.0000
# 889     30.0000
# Name: Fare, Length: 122, dtype: float64
# __________
# (2, 'female')
# 9      30.0708
# 15     16.0000
# 41     21.0000
# 43     41.5792
# 53     26.0000
#         ...
# 854    26.0000
# 865    13.0000
# 866    13.8583
# 874    24.0000
# 880    26.0000
# Name: Fare, Length: 76, dtype: float64
# __________
# (2, 'male')
# 17     13.0
# 20     26.0
# 21     13.0
# 33     10.5
# 70     10.5
#        ...
# 848    33.0
# 861    11.5
# 864    13.0
# 883    10.5
# 886    13.0
# Name: Fare, Length: 108, dtype: float64
# ...

# %%
df_train[]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-111-2ba6903fc07c> in <module>
# ----> 1 df_train[[df_train['Sex']=='female']]
#
# D:\Python_Installer\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3013         # Do we have a (boolean) 1d indexer?
#    3014         if com.is_bool_indexer(key):
# -> 3015             return self._getitem_bool_array(key)
#    3016
#    3017         # We are left with two options: a single key, and a collection of keys,
#
# D:\Python_Installer\lib\site-packages\pandas\core\frame.py in _getitem_bool_array(self, key)
#    3060             )
#    3061         elif len(key) != len(self.index):
# -> 3062             raise ValueError(
#    3063                 f"Item wrong length {len(key)} instead of {len(self.index)}."
#    3064             )
#
# ValueError: Item wrong length 1 instead of 891.

# %%
df_train[df_train['Pclass']==1 and df_train['Pclass']=='1'   ]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-148-e29b81181249> in <module>
# ----> 1 df_train[df_train['Pclass']==1 and df_train['Pclass']=='1'   ]
#
# D:\Python_Installer\lib\site-packages\pandas\core\generic.py in __nonzero__(self)
#    1440     @final
#    1441     def __nonzero__(self):
# -> 1442         raise ValueError(
#    1443             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1444             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
df_train['Pclass']=='1'
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888    False
# 889    False
# 890    False
# Name: Pclass, Length: 891, dtype: bool

# %%
df_train['Sex']=='female'
# Out:
# 0      False
# 1       True
# 2       True
# 3       True
# 4      False
#        ...
# 886    False
# 887     True
# 888     True
# 889    False
# 890    False
# Name: Sex, Length: 891, dtype: bool
