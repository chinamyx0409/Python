# %%
#in juptyer 1 plot

#bokeh serve --show excercises_slider.py
#ctrl-c to quit

# %%
from bokeh.plotting import figure, output_file, show
import random 
count = 20
x = range(count)
y = random.sample(range(10,100), count)

p = figure() #figure is a type of plot

p.circle(
    x,
    y,
    size =10,
    color ='red',
    legend_label = 'circle'
)

p.line(
    x,
    y,
    color ='blue',
    legend_label = 'line'
)

p.triangle(

    y,
    x,
    color ='gold',
    legend_label = 'triangle',
    size = 10
)

#for jupyter
output_file('first_graph.html')#to prevent diferent tabel
show(p)


#save this file to db2 and name it as first_graph.py

# %%
#in visio 1 plot

# %%
from bokeh.io import curdoc
from bokeh.layouts import row, column, gridplot

from bokeh.plotting import figure, output_file, show
import random 
count = 20
x = range(count)
y = random.sample(range(10,100), count)

p = figure() #figure is a type of plot

p.circle(
    x,
    y,
    size =10,
    color ='red',
    legend_label = 'circle'
)

p.line(
    x,
    y,
    color ='blue',
    legend_label = 'line'
)

p.triangle(
    y,
    x,
    color ='gold',
    legend_label = 'triangle',
    size = 20
)

#for jupyter
#output_file('first_graph.html')#to prevent diferent tabel
#show(p)
#save this file to db2 and name it as first_graph.py

#for visi0
curdoc().add_root(row(p, width = 500))
curdoc.title() = 'First Graph'

#launch ANOTHER TERMINAL of anaconda prompt
#Do not touch existing
#CD into DB2

# %% [markdown]
# run this after naviaget to db2
# %bokeh serve --show first_graph.py
# local host 5000

# %%
#group using a list
#bokeh server using notes
#in visio 3 plots


from bokeh.plotting import curdoc
from bokeh.layouts import row, column, gridplot

import random 
count = 20
x = range(count)
y = random.sample(range(10,100), count)

p1 = figure() #figure is a type of plot

p1.circle(
    x,
    y,
    size =10,
    color ='red',
    legend_label = 'circle'
)



p2 = figure() #figure is a type of plot
p2.line(
    x,
    y,
    color ='blue',
    legend_label = 'line'
)


p3 = figure() #figure is a type of plot
p3.triangle(
    y,
    x,
    color ='gold',
    legend_label = 'triangle',
    size = 20


)

#for visi0
curdoc().add_root(row(p1, p2, sizing_mode='scale_width'))
curdoc().title = 'First Graph'

# %%
#group using a list
#bokeh server using notes

#from bokeh.plotting import figure, output_file, show
#from bokeh.plotting import curdoc
#from bokeh.layouts import row, column, gridplot

from bokeh.layouts import gridplot

import random 
count = 20
x = range(count)
y = random.sample(range(10,100), count)

p1 = figure() #figure is a type of plot

p1.circle(
    x,
    y,
    size =10,
    color ='red',
    legend_label = 'circle'
)



p2 = figure() #figure is a type of plot
p2.line(
    x,
    y,
    color ='blue',
    legend_label = 'line'
)


p3 = figure() #figure is a type of plot
p3.triangle(
    y,
    x,
    color ='gold',
    legend_label = 'triangle',
    size = 20


)


curdoc().add_root(
    gridplot(
        [
            [p1, p2], 
            [None, p3]
        ], 
        plot_width=250,
        plot_height=250)
)

curdoc().title = 'fourth_graph'
#stop server using ctrl - c and wait to sotp server

# %%
# no time to arrange plots , allow automation arrangement of pltos

from bokeh.plotting import figure, output_file, show
from bokeh.plotting import curdoc
from bokeh.layouts import row, column, gridplot

import random 
count = 20
x = range(count)
y = random.sample(range(10,100), count)

p1 = figure() #figure is a type of plot

p1.circle(
    x,
    y,
    size =10,
    color ='red',
    legend_label = 'circle'
)



p2 = figure() #figure is a type of plot
p2.line(
    x,
    y,
    color ='blue',
    legend_label = 'line'
)


p3 = figure() #figure is a type of plot
p3.triangle(
    y,
    x,
    color ='gold',
    legend_label = 'triangle',
    size = 20


)


curdoc().add_root(
    gridplot(
        [p1, p2,p3], 
        #ncols=2,
        #ncols=1,
        ncols=3,
        plot_width=250,
        plot_height=250)
)

curdoc().title = 'fourth_graph'
#stop server using ctrl - c and wait to sotp server

# %%
#graph cosine
from bokeh.plotting import figure, output_file, show #juptyer noteboook 
import numpy as np
import math
from bokeh.layouts import gridplot

# 360 degress = 2pi radian
x = np.arange(0, math.pi*2, 0.05)
y_sin = np.sin(x)
y_cos = np.cos(x)
y_tan = np.tan(x)

print(x)
print(y)

p1 = figure()
p1.line( x, y_sin, color ='blue', legend_label = 'sine curve', line_width= 5)


p2 = figure()
p2.line( x, y_cos, color ='red', legend_label = 'cosine curve')


p3 = figure()
p3.line( x, y_tan, color ='green', legend_label = 'tanget curve')

grid = gridplot(
    [p1,p2,p3],
    ncols = 2,
    sizing_mode = 'scale_height'

)

#for jupyter
output_file('sine.html')#to prevent diferent tabel
show(grid)
#show(p1)
#show(p2)
#show(p3)
# Out:
# [0.   0.05 0.1  0.15 0.2  0.25 0.3  0.35 0.4  0.45 0.5  0.55 0.6  0.65
#  0.7  0.75 0.8  0.85 0.9  0.95 1.   1.05 1.1  1.15 1.2  1.25 1.3  1.35
#  1.4  1.45 1.5  1.55 1.6  1.65 1.7  1.75 1.8  1.85 1.9  1.95 2.   2.05
#  2.1  2.15 2.2  2.25 2.3  2.35 2.4  2.45 2.5  2.55 2.6  2.65 2.7  2.75
#  2.8  2.85 2.9  2.95 3.   3.05 3.1  3.15 3.2  3.25 3.3  3.35 3.4  3.45
#  3.5  3.55 3.6  3.65 3.7  3.75 3.8  3.85 3.9  3.95 4.   4.05 4.1  4.15
#  4.2  4.25 4.3  4.35 4.4  4.45 4.5  4.55 4.6  4.65 4.7  4.75 4.8  4.85
#  4.9  4.95 5.   5.05 5.1  5.15 5.2  5.25 5.3  5.35 5.4  5.45 5.5  5.55
#  5.6  5.65 5.7  5.75 5.8  5.85 5.9  5.95 6.   6.05 6.1  6.15 6.2  6.25]
# [ 0.          0.04997917  0.09983342  0.14943813  0.19866933  0.24740396
#   0.29552021  0.34289781  0.38941834  0.43496553  0.47942554  0.52268723
#   0.56464247  0.60518641  0.64421769  0.68163876  0.71735609  0.75128041
#   0.78332691  0.8134155   0.84147098  0.86742323  0.89120736  0.91276394
# ...
